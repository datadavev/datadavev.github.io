# %%
from nltk.corpus import wordnet as wn
import nltk.corpus.reader.wordnet
from nltk.corpus import wordnet_ic
brown_ic = wordnet_ic.ic('ic-brown.dat')


def tsyn(s):
    res = [
        s.name(),
        f"  {', '.join(s.lemma_names())}",
        f"  {s.definition()}",
    ]
    return "\n".join(res)

def syn_broader(s, depth=1):
    hyper = lambda s: s.hypernyms()
    for t in s.closure(hyper, depth=depth):
        yield t

def syn_narrower(s, depth=1):
    hyper = lambda s: s.hyponyms()
    for t in s.closure(hyper, depth=depth):
        yield t  
        
def syn_d(a, b):
    return a.path_similarity(b)

# %%
term = wn.synset("water.n.01")
print(tsyn(term))
for t in syn_broader(term):
    print(f"{t.name():25} {syn_d(term, t):.3f}")
# Out:
# water.n.06
#   water
#   a liquid necessary for the life of most animals and plants
# food.n.01                 0.500
# liquid.n.01               0.500
# nutrient.n.02             0.500

# %%
for t in syn_narrower(term, depth=1):
    print(f"{syn_d(term, t):6.3f} {tsyn(t)}\n---")
# Out:
#  0.500 branch_water.n.01
#   branch_water
#   pure natural water from a stream or brook; often distinguished from soda water
# ---
#  0.500 drinking_water.n.01
#   drinking_water
#   water suitable for drinking
# ---
#  0.500 spring_water.n.02
#   spring_water
#   water from a spring
# ---
