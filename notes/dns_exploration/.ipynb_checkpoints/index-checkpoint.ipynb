# %% [raw]
# ---
# title: DNS Exploration
# author: Dave Vieglais
# categories:
#   - sysadmin
#   - DNS
# abstract: Some notes on exploring DNS
# ---

# %% [markdown]
# IP Address:

# %%
dig -s geosamples.org
